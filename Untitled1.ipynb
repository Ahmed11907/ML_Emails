# %%
import string

import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ahmed\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('spam_ham_dataset.csv')

# %%
df['text']=df['text'].apply(lambda x:x.replace('\r\n',' '))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
stemmer = PorterStemmer()
corpus = []

stopwords_set=set(stopwords.words('english'))
for i in range(len(df)):
    text=df['text'].iloc[i].lower()
    text = text.translate(str.maketrans('','',string.punctuation)).split()
    text= [stemmer.stem(word) for word in text if word not in stopwords_set]
    text = ' '.join(text)
    corpus.append(text)

# %%
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(corpus).toarray()
y = df.label_num

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.4)

# %%
clf = RandomForestClassifier(n_jobs=-1)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_jobs=-1)

# %%
clf.score(X_test,y_test)
# Out:
# 0.9758337361043983

# %%
email_to_classify = df.text.values[1] #change the value in order to test different email

# %%
email_to_classify
# Out:
# 'Subject: hpl nom for january 9 , 2001 ( see attached file : hplnol 09 . xls ) - hplnol 09 . xls'

# %%
email_text = email_to_classify.lower().translate(str.maketrans('','',string.punctuation)).split()
email_text = [stemmer.stem(word) for word in text if word not in stopwords_set]
email_text = ' '.join(email_text)

email_corpus= [email_text]

X_email = vectorizer.transform(email_corpus)

# %%
clf.predict(X_email)
# Out:
# array([1], dtype=int64)

# %%
df.label_num.iloc[1]#change the value in order to test different email
# Out:
# 0

# %%
pip install voila ipywidgets
# Out:
# Requirement already satisfied: voila in c:\users\ahmed\desktop\anaconda\lib\site-packages (0.5.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: ipywidgets in c:\users\ahmed\desktop\anaconda\lib\site-packages (7.8.1)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (8.6.0)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (5.7.2)
# Requirement already satisfied: jupyter-server<3,>=2.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (2.25.1)
# Requirement already satisfied: nbclient>=0.4.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (0.8.0)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (7.10.0)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (5.14.3)
# Requirement already satisfied: websockets>=9.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from voila) (12.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (6.4.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-core>=4.11.0->voila) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-core>=4.11.0->voila) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (3.1.4)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (23.2)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-server<3,>=2.0.0->voila) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.0.8)
# Requirement already satisfied: idna>=2.8 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ahmed\desktop\anaconda\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.0->voila) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2024.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ahmed\desktop\anaconda\lib\site-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\ahmed\desktop\anaconda\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.0->voila) (2.16.2)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: wcwidth in c:\users\ahmed\desktop\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.5)
# Requirement already satisfied: executing in c:\users\ahmed\desktop\anaconda\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ahmed\desktop\anaconda\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ahmed\desktop\anaconda\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (2.1)
# Requirement already satisfied: uri-template in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (24.6.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.0->voila) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\ahmed\desktop\anaconda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.0->voila) (2.21)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ahmed\desktop\anaconda\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ahmed\desktop\anaconda\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (1.2.3)

# %%
import ipywidgets as widget
from IPython.display import display

slider = widgets.IntSlider(value=5, min=0, max=10, step=1,
description='Slider:')
display(slider)

# %%
git init
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Ahmed11907/ML_Emails.git
git push -u origin main
# Out:
#   Cell In[25], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
